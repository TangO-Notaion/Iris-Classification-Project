# %% [markdown]
# ### **Setup**

# %%
# %pip install pandas numpy scikit-learn seaborn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %% [markdown]
# ### **Data analysis**

# %%
df = pd.read_csv('/content/drive/MyDrive/iris.csv')
df.sample(5)
# Out:
#      Sepal_Length(Cm)  Sepal_Width(Cm)  Petal_Length(Cm)  Petal_Width(Cm)  \
# 7                 5.0              3.4               1.5              0.2
# 140               6.7              3.1               5.6              2.4
# 16                5.4              3.9               1.3              0.4
# 53                5.5              2.3               4.0              1.3
# 22                4.6              3.6               1.0              0.2
#
#         Species
# 7        setosa
# 140   virginica
# 16       setosa
# 53   versicolor
# 22       setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ### **Train**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['Sepal_Length(Cm)','Sepal_Width(Cm)','Petal_Length(Cm)','Petal_Width(Cm)']], df['Species'], random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier().fit(x_train, y_train)

# %%
pred = model.predict(x_test)
model.score(x_test, y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# ### **Test**

# %%
#before testing
print('range of Sepal_Length(Cm)',df['Sepal_Length(Cm)'].min(),'to',df['Sepal_Length(Cm)'].max())
print('range of Sepal_Width(Cm)',df['Sepal_Width(Cm)'].min(),'to',df['Sepal_Width(Cm)'].max())
print('range of Petal_Length(Cm)',df['Petal_Length(Cm)'].min(),'to',df['Petal_Length(Cm)'].max())
print('range of Petal_Width(Cm)',df['Petal_Width(Cm)'].min(),'to',df['Petal_Width(Cm)'].max())
# Out:
# range of Sepal_Length(Cm) 4.3 to 7.9
# range of Sepal_Width(Cm) 2.0 to 4.4
# range of Petal_Length(Cm) 1.0 to 6.9
# range of Petal_Width(Cm) 0.1 to 2.5

# %%
test = [4.0, 3.4, 5.6, 3.0]
ans = model.predict([test])
print('result :',ans[0])
# Out:
# result : virginica
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
